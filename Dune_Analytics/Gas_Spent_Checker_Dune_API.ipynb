# %% [markdown]
# # About
#
# - This Python notebook is a quickstart for using Dune API to fetch data. 📶
#
# - Input you API key to run this quickstart 🔑. Replace the query ID to fetch data for your query ⌨️.
#
# ---
#
# ## Set up
# - Install Dune API SDK (run `pip install dune_client`)
# - Obtain an API key (https://docs.dune.com/api-reference/overview/authentication)

# %%
# !pip install dune_client
# !pip install dataclasses_json

# %%
from dune_client.types import QueryParameter
from dune_client.client import DuneClient
from dune_client.query import QueryBase

# %% [markdown]
# ### Input our Dune API key here and query ID here 👇

# %%
dune_api_key = '<paste your api key here>' # input your API key, to create one follow guide here https://docs.dune.com/api-reference/overview/authentication

# %%
dune = DuneClient(
    api_key=dune_api_key,
    base_url="https://api.dune.com",
    request_timeout=(300) # request will time out after 300 seconds
)

# %% [markdown]
# ## Get latest result for [Gas Spent Checker)](https://dune.com/queries/2860880)

# %%
# Define query parameters
start_date = "2024-01-01 00:00:00"
end_date = "2024-06-01 00:00:00"
wallet_address = "0xAda62a424E8672634052DaFE4ecAe86cdf9a23B7"

# %%
query = QueryBase(
    query_id=2860880,
    params=[
        QueryParameter.date_type(name="Start Date", value=start_date),
        QueryParameter.date_type(name="End Date", value=end_date),
        QueryParameter.text_type(name="Wallet Address", value=wallet_address),
    ],
)

# %%
query_result = dune.run_query_dataframe(query=query)

# %%
query_result
# Out:
#                                           Blockchain  |  #TXs  \
# 0  <a href='https://debank.com/profile/0xada62a42...  |    28
# 1  <a href='https://optimistic.etherscan.io/addre...  |     6
# 2  <a href='https://etherscan.io/address/0xada62a...  |     3
# 3  <a href='https://bscscan.com/address/0xada62a4...  |     4
# 4  <a href='https://arbiscan.io/address/0xada62a4...  |    15
#
#             Fee (Native)   |  Fee (USD)  Fee (ETH)
# 0                  <nil>   |   7.617825   0.002078
# 1  0.0008999485991987561   |   3.473935   0.000900
# 2      0.000816871413288   |   2.797157   0.000817
# 3  0.0015746599999999999   |   0.848096   0.000222
# 4         0.000139695446   |   0.498636   0.000140
